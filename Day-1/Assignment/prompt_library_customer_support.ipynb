# %% [markdown]
# # 📘 Assignment 1: Prompt Library for Customer Support

# %% [markdown]
# ## 🧩 Objective
# Design prompts for:
# - Order status
# - Troubleshooting
# - Refunds
#
# Evaluate based on clarity, accuracy, conciseness.

# %% [markdown]
# ## 📦 Prompt Library

# %% [markdown]
# ### 🔹 Order Status Prompts

# %%
prompt_1 = "Where is my order #12345?"
print(prompt_1)

# %%
prompt_2 = "My order hasn’t arrived yet."
print(prompt_2)

# %% [markdown]
# ### 🔧 Troubleshooting Prompts

# %%
prompt_3 = "App not working"
print(prompt_3)

# %%
prompt_4 = "Cannot login"
print(prompt_4)

# %% [markdown]
# ### 💰 Refund Prompts

# %%
prompt_5 = "Request refund"
print(prompt_5)

# %%
prompt_6 = "Refund rejected"
print(prompt_6)

# %% [markdown]
# ## 📊 Evaluation
# | Type | Clarity | Accuracy | Conciseness |
# |------|--------|---------|-------------|
# | Order | High | High | Medium |
# | Troubleshooting | High | Medium | High |
# | Refund | High | High | High |

# %% [markdown]
# ## 🏁 Conclusion
# Prompts improve automation efficiency.
